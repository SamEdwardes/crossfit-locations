# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import unicodedata
import datetime
import json
import plotly.express as px

# %% [markdown]
# # CrossFit affiliate analysis
#
# Analysing the current landscape of CrossFit affiliates.
#
# **Resources**:
#
# - https://www.crossfit.com/affiliate-list
# - https://nominatim.org/release-docs/latest/
# - https://plotly.com/python/mapbox-county-choropleth/

# %% [markdown]
# # Load and parse CrossFit data

# %%
with open('data/cf-affiliates_2020-06-18.html') as f:
    html = f.read()

soup = BeautifulSoup(html)
date = datetime.datetime.now()

# %%
cf_locations = {
    'gym_name' : [],
    'gym_url': [],
    'location' : []
}

affiliate_table = soup.find('table', {'id': 'affiliateTable'})
for tr in affiliate_table.find('tbody').find_all('tr'):
    td = tr.find_all('td')
    cf_locations['gym_name'].append(td[0].text)
    cf_locations['gym_url'].append(td[0].a['href'])
    cf_locations['location'].append(td[1].text)

print('Number of affiliates, numer of data points:')
print(pd.DataFrame(cf_locations).shape)
# Out:
# Number of affiliates, numer of data points:
# (8877, 3)

# %% [markdown]
# # Clean CrossFit data

# %%
def clean_text(text):
    """Helper function to clean text data
    
    Parameters
    ----------
    text : str
        The text to clean
        
    Rerturns
    --------
    str
        The clean text
        
    Examples
    --------
    >>> s = clean_text('    àéêöheLlo')
    >>> print(s)
    aeeohello
    """
    # strip accents
    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")
    
    # lower case and strip
    test = str(text)
    text = text.lower()
    text = text.strip()

    return text

# %%
# clean the data
cf_locations_df = pd.DataFrame(cf_locations)
cf_locations_df['gym_name'] = cf_locations_df['gym_name'].apply(clean_text)
cf_locations_df['location'] = cf_locations_df['location'].apply(clean_text)
cf_locations_df[['city', 'state_prov_country']] = cf_locations_df['location'].str.split(',', expand=True, n=1)
cf_locations_df['city'] = cf_locations_df['city'].apply(clean_text)
cf_locations_df['state_prov_country'] = cf_locations_df['state_prov_country'].apply(clean_text)

cf_locations_df.head(10)
# Out:
#                            gym_name  \
# 0                  crossfit geldrop
# 1                  benmore crossfit
# 2         crossfit movement factory
# 3  crossfit chapelle-lez-herlaimont
# 4                     crossfit 1848
# 5                 crossfit flipside
# 6                     crossfit 1825
# 7                  crossfit altisea
# 8                      crossfit bsc
# 9                       crossfit bg
#
#                                              gym_url  \
# 0                   https://www.crossfit-geldrop.nl/
# 1  https://benmorenutritionfitness.com/v2/#page/b...
# 2  https://www.movementrehab.hr/crossfitmovementf...
# 3   http://www.crossfit-chapelle-lez-herlaimont.com/
# 4                       http://www.crossfit1848.com/
# 5                       http://crossfit-flipside.de/
# 6            https://crossfit1825.wixsite.com/cf1825
# 7                   https://www.crossfitaltisea.com/
# 8                https://www.bengkelsnc.com/crossfit
# 9                            https://crossfitbg.cat/
#
#                            location                     city  \
# 0              geldrop, netherlands                  geldrop
# 1       ballycastle, united kingdom              ballycastle
# 2                    split, croatia                    split
# 3  chapelle-lez-herlaimont, belgium  chapelle-lez-herlaimont
# 4              saint denis, reunion              saint denis
# 5                paderborn, germany                paderborn
# 6                    washington, il               washington
# 7                 toulouges, france                toulouges
# 8                jakarta, indonesia                  jakarta
# 9                      berga, spain                    berga
#
#   state_prov_country
# 0        netherlands
# 1     united kingdom
# 2            croatia
# 3            belgium
# 4            reunion
# 5            germany
# 6                 il
# 7             france
# 8          indonesia
# 9              spain

# %% [markdown]
# # GeoJson data

# %% [markdown]
# ## GeoJson Helper functions

# %%
def query_open_maps(query):
    """Find geoJSON data
    
    Parameters
    ----------
    query : str
        The location to query
        
    Returns
    -------
    dict
        best geoJSON results.
        
    Examples
    --------
    >>> query_open_maps('toronto, on')
    """
    url = 'https://nominatim.openstreetmap.org/'
    params = {
        'format': 'geojson',
        'polygon_geojson': 1,
        'limit': 5,
        'q': query,
    }
    r = requests.get(url, params)
    
    # loop through the results, and take the top result that finds
    # a geometry type of polygon    
    for i in json.loads(r.text)['features']:
        geo_json = i
        if geo_json['geometry']['type'] == 'Polygon':
            print('geojson data found!')
            return geo_json
    print(f'no geojson data found for: {query}')
    return None

# %%
def search_geojson(x):
    """Helper function to search the geojson data and return place_id
    
    Examples
    --------
    >>> print(search_geojson('houston, tx'))
    >>> print(search_geojson('toronto'))
    """
    for i in geo_json_dict['features']:
        city = i['properties']['location_id']
        if x == city:
            return i['properties']['place_id']
        else:
            continue
    return np.nan

# %% [markdown]
# ## Load existing JSON data

# %% [markdown]
# Load the existing JSON data if there is any already saved.

# %%
try:
    geo_json_dict = json.load(open('data/geo_json.json'))
except FileNotFoundError:
    geo_json_dict = {
    'type': 'FeatureCollection',
     'features': []
}
    
print(len(geo_json_dict['features']))
# Out:
# 365

# %% [markdown]
# Get a unique list of locations and see which already have geoJSON data

# %%
city_mapping = pd.DataFrame(cf_locations_df['location'].value_counts()).reset_index()
city_mapping = city_mapping.rename(columns={'index': 'location_id', 'location': 'num_gyms'})
city_mapping['place_id'] = np.nan

# check existing geoJSON data
city_mapping['place_id'] = city_mapping['location_id'].apply(search_geojson)

# summarise 
num_locations = city_mapping.shape[0]
num_geo_json = city_mapping.query('~place_id.isnull()').shape[0]
print(f'geo json data found for {num_geo_json} of {num_locations} locations.')
city_mapping.head(20)
# Out:
# geo json data found for 365 of 5629 locations.
#                location_id  num_gyms     place_id
# 0        sao paulo, brazil        41  235483727.0
# 1              houston, tx        38  235682504.0
# 2          san antonio, tx        29          NaN
# 3              chicago, il        27  235244846.0
# 4              seattle, wa        25  235470814.0
# 5               denver, co        23  234888713.0
# 6            san diego, ca        23  235088160.0
# 7              orlando, fl        21          NaN
# 8                miami, fl        21  235588862.0
# 9   london, united kingdom        21  235147154.0
# 10           las vegas, nv        20  235352046.0
# 11              austin, tx        20  235657895.0
# 12             atlanta, ga        20          NaN
# 13         los angeles, ca        19  279653657.0
# 14           brisbane, qld        18          NaN
# 15              dallas, tx        18  235674375.0
# 16        barcelona, spain        18          NaN
# 17            portland, or        18          NaN
# 18           charlotte, nc        18  290564703.0
# 19              tucson, az        16  235499073.0

# %% [markdown]
# ## Update geoJSON data for missing locations

# %%
# for i in range(0, 500):
for i in range(500, 1500):
# for i in range(0, 500):
# for i in range(0, 500):
    
    location = city_mapping.loc[i, 'location_id']
    print('=' * 64)
    print('#', i, ': ', location, sep='')
    
    # check if geoJSON data already exists for city
    if ~np.isnan(city_mapping.loc[i, 'place_id']):
        print('geo_json already exists')
        continue
    
    # call the open maps api to get data
    geo_json = query_open_maps(location)
    if geo_json is None:
        city_mapping.loc[i, 'place_id'] = np.nan
    else:
        geo_json['properties']['location_id'] = city_mapping.loc[i, 'location_id']
        geo_json_dict['features'].append(geo_json)
        city_mapping.loc[i, 'place_id'] = int(geo_json['properties']['place_id'])
            
# save the update_geoJSON data
with open('data/geo_json.json', 'w') as f:
    json.dump(geo_json_dict, f, indent=4)

city_mapping.head(20)
# Out:
# ================================================================
# #500: largo, fl
# no geojson data found for: largo, fl
# ================================================================
# #501: longview, tx
# geojson data found!
# ================================================================
# #502: wheat ridge, co
# geo_json already exists
# ================================================================
# #503: recife, brazil
# geojson data found!
# ================================================================
# #504: dayton, oh
# no geojson data found for: dayton, oh
# ================================================================
# #505: greenville, nc
# no geojson data found for: greenville, nc
# ================================================================
# #506: rome, ga
# no geojson data found for: rome, ga
# ================================================================
# #507: new haven, ct
# geo_json already exists
# ================================================================
# #508: melbourne, fl
# geo_json already exists
# ================================================================
# #509: edmond, ok
# geo_json already exists
# ================================================================
# #510: riverside, ca
# geo_json already exists
# ================================================================
# #511: ferrara, italy
# geojson data found!
# ================================================================
# #512: tilburg, netherlands
# geo_json already exists
# ================================================================
# #513: bundaberg, qld
# geo_json already exists
# ================================================================
# #514: cleveland, tn
# geojson data found!
# ================================================================
# #515: bristol, united kingdom
# geojson data found!
# ================================================================
# #516: sterling, va
# geo_json already exists
# ================================================================
# #517: langley, bc
# geojson data found!
# ================================================================
# #518: norwood, ma
# geo_json already exists
# ================================================================
# #519: hamilton, new zealand
# no geojson data found for: hamilton, new zealand
# ================================================================
# #520: alameda, ca
# no geojson data found for: alameda, ca
# ================================================================
# #521: long island city, ny
# no geojson data found for: long island city, ny
# ================================================================
# #522: dublin, oh
# geojson data found!
# ================================================================
# #523: johnson city, tn
# no geojson data found for: johnson city, tn
# ================================================================
# #524: forney, tx
# geo_json already exists
# ================================================================
# #525: bergen, norway
# geo_json already exists
# ================================================================
# #526: rocklin, ca
# geo_json already exists
# ================================================================
# #527: decatur, il
# geo_json already exists
# ================================================================
# #528: shreveport, la
# no geojson data found for: shreveport, la
# ================================================================
# #529: victorville, ca
# geo_json already exists
# ================================================================
# #530: kalamazoo, mi
# geo_json already exists
# ================================================================
# #531: frosinone, italy
# geojson data found!
# ================================================================
# #532: santa monica, ca
# no geojson data found for: santa monica, ca
# ================================================================
# #533: poulsbo, wa
# no geojson data found for: poulsbo, wa
# ================================================================
# #534: broken arrow, ok
# geo_json already exists
# ================================================================
# #535: weatherford, tx
# geo_json already exists
# ================================================================
# #536: bournemouth, united kingdom
# geo_json already exists
# ================================================================
# #537: wiesbaden, germany
# geo_json already exists
# ================================================================
# #538: brea, ca
# geo_json already exists
# ================================================================
# #539: montgomery, tx
# geo_json already exists
# ================================================================
# #540: syosset, ny
# geojson data found!
# ================================================================
# #541: chico, ca
# no geojson data found for: chico, ca
# ================================================================
# #542: abilene, tx
# geojson data found!
# ================================================================
# #543: roanoke, va
# geojson data found!
# ================================================================
# #544: port saint lucie, fl
# no geojson data found for: port saint lucie, fl
# ================================================================
# #545: york, united kingdom
# geo_json already exists
# ================================================================
# #546: campbell, ca
# no geojson data found for: campbell, ca
# ================================================================
# #547: hollywood, fl
# no geojson data found for: hollywood, fl
# ================================================================
# #548: naperville, il
# geojson data found!
# ================================================================
# #549: odessa, fl
# geo_json already exists
# ================================================================
# #550: abu dhabi, united arab emirates
# geo_json already exists
# ================================================================
# #551: darmstadt, germany
# geojson data found!
# ================================================================
# #552: madison, al
# geo_json already exists
# ================================================================
# #553: aalborg, denmark
# no geojson data found for: aalborg, denmark
# ================================================================
# #554: latrobe, pa
# geo_json already exists
# ================================================================
# #555: nampa, id
# no geojson data found for: nampa, id
# ================================================================
# #556: frankfurt am main, germany
# geojson data found!
# ================================================================
# #557: daegu, korea, republic of
# no geojson data found for: daegu, korea, republic of
# ================================================================
# #558: holstebro, denmark
# geojson data found!
# ================================================================
# #559: montesson, france
# geojson data found!
# ================================================================
# #560: gloucester, united kingdom
# geojson data found!
# ================================================================
# #561: khobar, saudi arabia
# no geojson data found for: khobar, saudi arabia
# ================================================================
# #562: kirrawee, nsw
# no geojson data found for: kirrawee, nsw
# ================================================================
# #563: dahlonega, ga
# no geojson data found for: dahlonega, ga
# ================================================================
# #564: oxnard, ca
# geojson data found!
# ================================================================
# #565: alessandria, italy
# geojson data found!
# ================================================================
# #566: moss, norway
# geojson data found!
# ================================================================
# #567: muncie, in
# geojson data found!
# ================================================================
# #568: peterborough, on
# geojson data found!
# ================================================================
# #569: hoboken, nj
# geojson data found!
# ================================================================
# #570: marion, oh
# geojson data found!
# ================================================================
# #571: morristown, nj
# geojson data found!
# ================================================================
# #572: rogers, ar
# no geojson data found for: rogers, ar
# ================================================================
# #573: sherman, tx
# geojson data found!
# ================================================================
# #574: corte madera, ca
# geojson data found!
# ================================================================
# #575: ponta grossa, brazil
# geojson data found!
# ================================================================
# #576: oxford, ms
# geojson data found!
# ================================================================
# #577: marrakech, morocco
# geojson data found!
# ================================================================
# #578: spanish fork, ut
# geojson data found!
# ================================================================
# #579: lomita, ca
# geojson data found!
# ================================================================
# #580: penticton, bc
# geojson data found!
# ================================================================
# #581: leominster, ma
# geojson data found!
# ================================================================
# #582: needham, ma
# geojson data found!
# ================================================================
# #583: luxembourg, luxembourg
# geojson data found!
# ================================================================
# #584: apple valley, mn
# geojson data found!
# ================================================================
# #585: mystic, ct
# geojson data found!
# ================================================================
# #586: capoterra, italy
# geojson data found!
# ================================================================
# #587: norwalk, ct
# geojson data found!
# ================================================================
# #588: collinsville, il
# geojson data found!
# ================================================================
# #589: charlottesville, va
# geojson data found!
# ================================================================
# #590: cordova, tn
# no geojson data found for: cordova, tn
# ================================================================
# #591: franklin, nc
# no geojson data found for: franklin, nc
# ================================================================
# #592: blacksburg, va
# geojson data found!
# ================================================================
# #593: bondi junction, nsw
# no geojson data found for: bondi junction, nsw
# ================================================================
# #594: spring hill, tn
# geojson data found!
# ================================================================
# #595: thibodaux, la
# geojson data found!
# ================================================================
# #596: dalton, ga
# no geojson data found for: dalton, ga
# ================================================================
# #597: natchitoches, la
# geojson data found!
# ================================================================
# #598: guangzhou, china
# geojson data found!
# ================================================================
# #599: wairau valley, new zealand
# no geojson data found for: wairau valley, new zealand
# ================================================================
# #600: hamilton, nj
# geojson data found!
# ================================================================
# #601: norcross, ga
# geojson data found!
# ================================================================
# #602: east stroudsburg, pa
# geojson data found!
# ================================================================
# #603: piacenza, italy
# geojson data found!
# ================================================================
# #604: cherry hill, nj
# geojson data found!
# ================================================================
# #605: chatsworth, ca
# geojson data found!
# ================================================================
# #606: governador valadares, brazil
# geojson data found!
# ================================================================
# #607: lebanon, tn
# no geojson data found for: lebanon, tn
# ================================================================
# #608: draper, ut
# geojson data found!
# ================================================================
# #609: forest hill, md
# no geojson data found for: forest hill, md
# ================================================================
# #610: queensbury, ny
# no geojson data found for: queensbury, ny
# ================================================================
# #611: iowa city, ia
# geojson data found!
# ================================================================
# #612: paderborn, germany
# geojson data found!
# ================================================================
# #613: dubuque, ia
# geojson data found!
# ================================================================
# #614: kennedale, tx
# geojson data found!
# ================================================================
# #615: cicero, ny
# no geojson data found for: cicero, ny
# ================================================================
# #616: chesterfield, mi
# geojson data found!
# ================================================================
# #617: klamath falls, or
# geojson data found!
# ================================================================
# #618: soldotna, ak
# geojson data found!
# ================================================================
# #619: cheyenne, wy
# no geojson data found for: cheyenne, wy
# ================================================================
# #620: wellington, new zealand
# geojson data found!
# ================================================================
# #621: kingston, ma
# geojson data found!
# ================================================================
# #622: quezon city, philippines
# geojson data found!
# ================================================================
# #623: goyang-si, korea, republic of
# no geojson data found for: goyang-si, korea, republic of
# ================================================================
# #624: pasadena, tx
# geojson data found!
# ================================================================
# #625: tempe, az
# geojson data found!
# ================================================================
# #626: hanover, ma
# geojson data found!
# ================================================================
# #627: hastings, new zealand
# geojson data found!
# ================================================================
# #628: salinas, ca
# no geojson data found for: salinas, ca
# ================================================================
# #629: san angelo, tx
# geojson data found!
# ================================================================
# #630: league city, tx
# geojson data found!
# ================================================================
# #631: passau, germany
# geojson data found!
# ================================================================
# #632: coquitlam, bc
# geojson data found!
# ================================================================
# #633: huntersville, nc
# no geojson data found for: huntersville, nc
# ================================================================
# #634: berlin, md
# geojson data found!
# ================================================================
# #635: decatur, al
# no geojson data found for: decatur, al
# ================================================================
# #636: sete lagoas, brazil
# geojson data found!
# ================================================================
# #637: cortez, co
# geojson data found!
# ================================================================
# #638: bellmore, ny
# geojson data found!
# ================================================================
# #639: crestview, fl
# geojson data found!
# ================================================================
# #640: bryan, tx
# geojson data found!
# ================================================================
# #641: nantes, france
# geojson data found!
# ================================================================
# #642: lausanne, switzerland
# no geojson data found for: lausanne, switzerland
# ================================================================
# #643: wausau, wi
# no geojson data found for: wausau, wi
# ================================================================
# #644: lansing, mi
# geojson data found!
# ================================================================
# #645: zanesville, oh
# geojson data found!
# ================================================================
# #646: monroe, mi
# geojson data found!
# ================================================================
# #647: farmington hills, mi
# geojson data found!
# ================================================================
# #648: daphne, al
# no geojson data found for: daphne, al
# ================================================================
# #649: elk city, ok
# geojson data found!
# ================================================================
# #650: merida, mexico
# geojson data found!
# ================================================================
# #651: madison, ct
# geojson data found!
# ================================================================
# #652: brunswick, ga
# geojson data found!
# ================================================================
# #653: verona, italy
# geojson data found!
# ================================================================
# #654: hattiesburg, ms
# geojson data found!
# ================================================================
# #655: kaysville, ut
# geojson data found!
# ================================================================
# #656: sonora, ca
# geojson data found!
# ================================================================
# #657: bethlehem, pa
# geojson data found!
# ================================================================
# #658: newcastle, nsw
# geojson data found!
# ================================================================
# #659: hudson, ny
# geojson data found!
# ================================================================
# #660: buccinasco, italy
# geojson data found!
# ================================================================
# #661: chicoutimi, qc
# geojson data found!
# ================================================================
# #662: arnhem, netherlands
# geojson data found!
# ================================================================
# #663: whangarei, new zealand
# geojson data found!
# ================================================================
# #664: royston, united kingdom
# geojson data found!
# ================================================================
# #665: madison, ms
# geojson data found!
# ================================================================
# #666: evanston, il
# geojson data found!
# ================================================================
# #667: elche, spain
# geojson data found!
# ================================================================
# #668: grand prairie, tx
# no geojson data found for: grand prairie, tx
# ================================================================
# #669: arlington, tn
# geojson data found!
# ================================================================
# #670: greer, sc
# no geojson data found for: greer, sc
# ================================================================
# #671: portage, wi
# geojson data found!
# ================================================================
# #672: mariestad, sweden
# no geojson data found for: mariestad, sweden
# ================================================================
# #673: sebring, fl
# no geojson data found for: sebring, fl
# ================================================================
# #674: harrisburg, pa
# geojson data found!
# ================================================================
# #675: liverpool, united kingdom
# geojson data found!
# ================================================================
# #676: heidelberg, germany
# geojson data found!
# ================================================================
# #677: vestavia, al
# no geojson data found for: vestavia, al
# ================================================================
# #678: silver spring, md
# geojson data found!
# ================================================================
# #679: jefferson city, mo
# geojson data found!
# ================================================================
# #680: regina, sk
# geojson data found!
# ================================================================
# #681: best, netherlands
# geojson data found!
# ================================================================
# #682: exeter, united kingdom
# geojson data found!
# ================================================================
# #683: caceres, spain

# %%
# summarise 
num_locations = city_mapping.shape[0]
num_geo_json = city_mapping.query('~place_id.isnull()').shape[0]
print(f'geo json data found for {num_geo_json} of {num_locations} locations.')

# %% [markdown]
# # Choropleth

# %%
fig = px.choropleth_mapbox(
    data_frame=city_mapping,
    geojson=geo_json_dict,
    locations='place_id',
    hover_name='location_id',
    color='num_gyms',
    color_continuous_scale='Viridis',
    featureidkey='properties.place_id',
    center={"lat": 40.0, "lon": -90.0},
    mapbox_style="carto-positron", 
    zoom=2
)

fig.show()
